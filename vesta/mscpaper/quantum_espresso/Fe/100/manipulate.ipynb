# %%
import pandas as pd

# %%
lst = '''Fe       0.000000000   0.000000000   7.420969522
Fe       1.421620000   1.421620000   8.816310011
Fe       0.000000000   0.000000000  10.284917971
Fe       1.421620000   1.421620000  11.741611309
Fe       0.000000000   0.000000000  13.186110074
Fe       1.421620000   1.421620000  14.631299388
Fe       0.000000000   0.000000000  16.088214385
Fe       1.421620000   1.421620000  17.557044066
Fe       0.000000000   0.000000000  18.951835657'''

# %%
lst1=[]
for i in range(len(lst.split('\n'))):
    lst1.append(lst.split('\n')[i].split())

# %%
lst1
# Out:
# [['Fe', '0.000000000', '0.000000000', '4.945540554'],
#  ['Fe', '1.421620000', '1.421620000', '6.336571054'],
#  ['Fe', '0.000000000', '0.000000000', '7.807893967'],
#  ['Fe', '1.421620000', '1.421620000', '9.250336884'],
#  ['Fe', '0.000000000', '0.000000000', '10.682077892'],
#  ['Fe', '1.421620000', '1.421620000', '12.112208624'],
#  ['Fe', '0.000000000', '0.000000000', '13.532388713'],
#  ['Fe', '1.421620000', '1.421620000', '14.951338572'],
#  ['Fe', '0.000000000', '0.000000000', '16.370287955'],
#  ['Fe', '1.421620000', '1.421620000', '17.790468520'],
#  ['Fe', '0.000000000', '0.000000000', '19.220598776'],
#  ['Fe', '1.421620000', '1.421620000', '20.652340260'],
#  ['Fe', '0.000000000', '0.000000000', '22.094782701'],
#  ['Fe', '1.421620000', '1.421620000', '23.566106090'],
#  ['Fe', '0.000000000', '0.000000000', '24.957136114']]

# %%
for j in range(len(lst1)):
    lst1[j][3] = str(float(lst1[j][3]) + 2.5)
    lst1[j].append('\n')

lst1
# Out:
# [['Fe', '0.000000000', '0.000000000', '7.445540554', '\n'],
#  ['Fe', '1.421620000', '1.421620000', '8.836571054', '\n'],
#  ['Fe', '0.000000000', '0.000000000', '10.307893967', '\n'],
#  ['Fe', '1.421620000', '1.421620000', '11.750336884', '\n'],
#  ['Fe', '0.000000000', '0.000000000', '13.182077892', '\n'],
#  ['Fe', '1.421620000', '1.421620000', '14.612208624', '\n'],
#  ['Fe', '0.000000000', '0.000000000', '16.032388713', '\n'],
#  ['Fe', '1.421620000', '1.421620000', '17.451338571999997', '\n'],
#  ['Fe', '0.000000000', '0.000000000', '18.870287955', '\n'],
#  ['Fe', '1.421620000', '1.421620000', '20.29046852', '\n'],
#  ['Fe', '0.000000000', '0.000000000', '21.720598776', '\n'],
#  ['Fe', '1.421620000', '1.421620000', '23.15234026', '\n'],
#  ['Fe', '0.000000000', '0.000000000', '24.594782701', '\n'],
#  ['Fe', '1.421620000', '1.421620000', '26.06610609', '\n'],
#  ['Fe', '0.000000000', '0.000000000', '27.457136114', '\n']]

# %%
for i in range(len(lst1)):
    for j in range(5):
        print(lst1[i][j],end ='  ')
# Out:
# Fe  0.000000000  0.000000000  7.445540554
#   Fe  1.421620000  1.421620000  8.836571054
#   Fe  0.000000000  0.000000000  10.307893967
#   Fe  1.421620000  1.421620000  11.750336884
#   Fe  0.000000000  0.000000000  13.182077892
#   Fe  1.421620000  1.421620000  14.612208624
#   Fe  0.000000000  0.000000000  16.032388713
#   Fe  1.421620000  1.421620000  17.451338571999997
#   Fe  0.000000000  0.000000000  18.870287955
#   Fe  1.421620000  1.421620000  20.29046852
#   Fe  0.000000000  0.000000000  21.720598776
#   Fe  1.421620000  1.421620000  23.15234026
#   Fe  0.000000000  0.000000000  24.594782701
#   Fe  1.421620000  1.421620000  26.06610609
#   Fe  0.000000000  0.000000000  27.457136114
