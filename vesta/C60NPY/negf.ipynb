# %%
def str_float_z(num,height):
    return str(float(num)+height)
def str_float_x(num):
    return str(float(num)+2.87*9.9896000000/2-4.9948000000/2)
def str_float_y(num):
    return str(float(num)+1.3*8.6512000000/2)

with open("c60py_negf.xyz",'w') as f1:
    with open("c60py(optimized).xyz") as f:
        for k,v in enumerate(f):
            lst = v.strip().split()
            if k == 0 or k == 1:
                f1.writelines(v)
                continue
            elif k<=91:
                lst[3]=str_float_z(lst[3],19.073360+2.384170 )
#                 lst[2]=str_float_y(lst[2])
#                 lst[1]=str_float_x(lst[1])
                lst.append('L0')
#                 pass
            elif k<=166:
                lst[3]=str_float_z(lst[3],19.073360+2.384170 )
                lst.append('S')
#                 lst[2]=str_float_y(lst[2])
#                 lst[1]=str_float_x(lst[1])
            elif k <=257:
                lst[3]=str_float_z(lst[3],19.073360+2.384170 )
#                 lst[2]=str_float_y(lst[2])
#                 lst[1]=str_float_x(lst[1])
                lst.append('R0')
            else:
                lst[3]=str_float_z(lst[3],19.073360+2.384170*2+ 32.4380322578-55.8220022578)
            line = '    '.join(lst) +'\n'
            f1.writelines(line)
#         for k,v in enumerate(right_lead):
#             print()
#             lst = v.strip().split()
#             lst[3]=str_float_z(lst[3],-22.872278212799998)
#             line = '    '.join(lst) +'\n'
#             f1.writelines(line)
        f.close()
    f1.close()
    
with open("c60py_negf.xyz") as f:
    print(f.read())
# Out:
#     256
#  i =      153, E =     -6420.4060793206
# Au    0.0000000000    0.0000000000    21.457530000000002    L0
# Au    8.7600000000    0.0000000000    21.457530000000002    L0
# Au    4.3800000000    7.5863820000    21.457530000000002    L0
# Au    13.1400000000    7.5863820000    21.457530000000002    L0
# Au    2.9200000000    0.0000000000    21.457530000000002    L0
# Au    11.6800000000    0.0000000000    21.457530000000002    L0
# Au    7.3000000000    7.5863820000    21.457530000000002    L0
# Au    16.0599990000    7.5863820000    21.457530000000002    L0
# Au    5.8400000000    0.0000000000    21.457530000000002    L0
# Au    14.6000000000    0.0000000000    21.457530000000002    L0
# Au    10.2200000000    7.5863820000    21.457530000000002    L0
# Au    18.9800000000    7.5863820000    21.457530000000002    L0
# Au    1.4600000000    2.5287940000    21.457530000000002    L0
# Au    10.2200000000    2.5287940000    21.457530000000002    L0
# ...

# %%
75.3530922578+2.3841700000
# Out:
# 77.7372622578

# %%
8.32470   2.88380
# Out:
#   File "<ipython-input-1-f44a91a403d6>", line 1
#     8.32470   2.88380
#                     ^
# SyntaxError: invalid syntax

# %%
5.05759*2
# Out:
# 10.11518
