# %%
S_HCN_up=[   -5.755673 ,  2.102695 , 0.626408]
S_HCN_down=[   5.525480, 1.040950,  0.814361]

S_target_up=[   9.1966474056  ,  5.0541413862  ,  39.9162663198    ]
S_target_down=[  7.9267809675  ,  5.9004541430   , 28.6869193214   ]

# %%
import math
import numpy as np
T_location = np.array(S_target_up)-np.array(S_target_down)

T_location_norm = T_location.copy()
T_location_norm= T_location_norm/np.linalg.norm(T_location_norm)
originVector = np.array(S_HCN_up)-np.array(S_HCN_down)
originVector_norm = originVector/np.linalg.norm(originVector)
print(originVector)
print(T_location)
sita = math.acos(T_location_norm@originVector_norm)
n_vector = np.cross(T_location_norm,originVector_norm) 

n_vector=n_vector/np.linalg.norm(n_vector)

n_vector_invert = np.array((
[0,-n_vector[2],n_vector[1]],
[n_vector[2],0,-n_vector[0]],
[-n_vector[1],n_vector[0],0]
))

print(sita)
print(n_vector_invert)


I = np.array((
[1 ,  0 , 0],
[0 ,  1 , 0],
[0 ,  0 , 1]
))

R_w2c = I + math.sin(sita)*n_vector_invert + n_vector_invert@(n_vector_invert)*(1-math.cos(sita))
# Out:
# [-11.281153   1.061745  -0.187953]
# [ 1.26986644 -0.84631276 11.229347  ]
# 1.706186723513376
# [[ 0.          0.06443218 -0.99363104]
#  [-0.06443218  0.          0.09244379]
#  [ 0.99363104 -0.09244379  0.        ]]

# %%
np.dot(originVector,R_w2c)
# Out:
# array([ 1.26986645, -0.84631276, 11.22934707])

# %%
S1= [ 7.712919650215356 , 10.240018110800758, -15.024762326175564]
Sshould=[11.4807219596 ,   5.1879040988 ,   28.4894975676   ]

# %%
with open("python_HCNmiddlech2030.xyz",'w') as f1:
    with open("HCNmiddlech2030.xyz") as f:
        for k,v in enumerate(f):
            if k == 0 or k == 1:
                line = v
            else:
                lst = v.strip().split()
                original = np.array([float(lst[1]),float(lst[2]),float(lst[3]) ])
                new=np.dot(original,R_w2c)
                for i in range(1,4):
                    lst[i] = str(new[i-1])
                line = '   '.join(lst)+"\n"
            f1.writelines(line)
        f.close()
    f1.close()
    
with open("python_HCNmiddlech2030.xyz") as f:
    print(f.read())
# Out:
# 36
#
# C   -0.9064159471169682   4.056055748676028   -2.512719266136431
# N   -1.394602150270334   4.603186052211175   -1.6017154212464997
# H   -0.4624625590586938   3.544038569174794   -3.3627994867469218
# C   0.8745992750962626   -0.08389896151706681   4.670019605444225
# C   1.7292433180536062   -1.0263908105550912   4.069966106643151
# C   1.2419569795831955   -1.8774933715659854   3.0711586241227224
# C   -0.09663766340670828   -1.8178555241229386   2.6438468397543398
# C   -0.47774933212400533   -0.03781986215377161   4.280203967857341
# C   -0.9474269385415534   -0.89399586454158   3.2800190681577344
# C   -0.6158402359158255   -1.4549213308219031   -2.2957244605824463
# H   1.9266441773401193   -2.593707949361014   2.6012135321612675
# S   1.426986842857844   1.0930268689088778   5.891560552397969
# H   -1.1600258206457832   0.6777305903502339   4.7508499910432445
# H   -1.998792364249884   -0.8312048958265992   2.9751048213587787
# ...

# %%
S_before=[  0.15712039624820584 ,1.9393396313801954 , -5.337786521252225]
S_after=[ 10.1896642657,  6.9401248065 ,  28.729184105 ]
Sdiff=[S_after[i] - S_before[i] for i in range(3)]

# %%
def str_float_z(num):
    return str(float(num)+ Sdiff[2])
def str_float_x(num):
    return str(float(num)+Sdiff[0])
def str_float_y(num):
    return str(float(num)+Sdiff[1])

with open("ch2030_HCNmiddle_negf.xyz",'w') as f1:
    with open("bifonazole_right_negf.xyz") as f:
        for k,v in enumerate(f):
            if k<=301:
                line = v
                f1.writelines(line)
        f.close()
    with open("python_HCNmiddlech2030.xyz") as f:
        for k,v in enumerate(f):
            if k == 0 or k == 1:
                continue
            else:
                lst = v.strip().split()
                lst[3]=str_float_z(lst[3])
                lst[2]=str_float_y(lst[2])
                lst[1]=str_float_x(lst[1])
                lst.append('S') 
                line = '    '.join(lst) +'\n'
                f1.writelines(line)
        f.close()
    with open("bifonazole_right_negf.xyz") as f:
        for k,v in enumerate(f):
            if k<=332:
                continue
            else:
                line = v
                f1.writelines(line)
        f.close()
    f1.close()
    
with open("ch2030_HCNmiddle_negf.xyz") as f:
    print(f.read())
# Out:
#  420
#  i =       82, E =     -3365.3998523447
# Au     0.000000     0.000000     0.000000     L3
# Au     8.760000     0.000000     0.000000     L3
# Au     4.380000     7.586382     0.000000     L3
# Au     13.140000     7.586382     0.000000     L3
# Au     2.920000     0.000000     0.000000     L3
# Au     11.680000     0.000000     0.000000     L3
# Au     7.300000     7.586382     0.000000     L3
# Au     16.059999     7.586382     0.000000     L3
# Au     5.840000     0.000000     0.000000     L3
# Au     10.220000     7.586382     0.000000     L3
# Au     1.460000     2.528794     0.000000     L3
# Au     10.220000     2.528794     0.000000     L3
# Au     5.840000     10.115176     0.000000     L3
# Au     14.600000     10.115176     0.000000     L3
# Au     4.380000     2.528794     0.000000     L3
# Au     13.140000     2.528794     0.000000     L3
# Au     8.760000     10.115176     0.000000     L3
# Au     17.520000     10.115176     0.000000     L3
# ...
