# %%
electrode_test

# %%
# add left electrode
#move to the centre
def str_float_z(num):
    return str(float(num)+21.51356+3+2.384170)
def str_float_x(num):
    return str(float(num)+0.6*14.6000/2-5.84/2)
def str_float_y(num):
    return str(float(num)+0.5*10.11518/2)

with open("left_25.xyz",'a') as f1:
    with open("left_electrode_25.xyz") as f2:
        for k,v in enumerate(f2):
            if k<=1:
                continue
            elif k<=109:
                lst = v.strip().split()
                lst[3]=str_float_z(lst[3])
#                 lst[2]=str_float_y(lst[2])
# #                 lst[1]=str_float_x(lst[1])
                lst[4]=('R0')
#             elif k<=217:
#                 lst = v.strip().split()
#                 lst[3]=str_float_z(lst[3])
# #                 lst[2]=str_float_y(lst[2])
# #                 lst[1]=str_float_x(lst[1])
#                 lst[4]=('R1')
#             elif k<=325:
#                 lst = v.strip().split()
#                 lst[3]=str_float_z(lst[3])
# #                 lst[2]=str_float_y(lst[2])
# #                 lst[1]=str_float_x(lst[1])
#                 lst[4]=('R2')
#             else:
#                 lst = v.strip().split()
#                 lst[3]=str_float_z(lst[3])
#                 lst[2]=str_float_y(lst[2])
#                 lst[1]=str_float_x(lst[1])
#                 lst[4]=('R3')
            line = '    '.join(lst) +'\n'
            f1.writelines(line)
        f2.close()
            
#     with open("S-ben-ch2-N-ch2^2-C60_boat3(optimized).xyz") as f:
# #         f1.write(electrode_test)
#         for k,v in enumerate(f):
#             if k<=76:
#                 continue
#             else:
#                 lst = v.strip().split()
# #                 lst[3]=str_float_z(lst[3])
#                 lst[2]=str_float_y(lst[2])
#                 lst[1]=str_float_x(lst[1])
#                 lst.append('S') 
#                 line = '    '.join(lst) +'\n'
#                 f1.writelines(line)
#         f.close()
#     f1.close()
    
with open("left.xyz") as f:
    print(f.read())
# Out:
# 192
#
# Au    0.000000    0.000000    0.000000    L3
# Au    8.760000    0.000000    0.000000    L3
# Au    4.380000    7.586382    0.000000    L3
# Au    13.140000    7.586382    0.000000    L3
# Au    2.920000    0.000000    0.000000    L3
# Au    7.300000    7.586382    0.000000    L3
# Au    5.840000    0.000000    0.000000    L3
# Au    10.220000    7.586382    0.000000    L3
# Au    1.460000    2.528794    0.000000    L3
# Au    10.220000    2.528794    0.000000    L3
# Au    4.380000    2.528794    0.000000    L3
# Au    7.300000    2.528794    0.000000    L3
# Au    2.920000    5.057588    0.000000    L3
# Au    11.680000    5.057588    0.000000    L3
# Au    5.840000    5.057588    0.000000    L3
# Au    8.760000    5.057588    0.000000    L3
# Au    1.460000    0.842931    2.384170    L3
# Au    10.220000    0.842931    2.384170    L3
# Au    5.840000    8.429314    2.384170    L3
# Au    14.600000    8.429314    2.384170    L3
# ...

# %%
# modify electrode
with open("test1.xyz",'w') as f1:
    with open("left_electrode_30.xyz") as f2:
        for k,v in enumerate(f2):
            if k<=1:
                continue
            if k<= 91:
                lst = v.strip().split()
                lst.append('R0')
            elif k <=181:
                lst = v.strip().split()
                lst.append('R1')
            elif k <=271:
                lst = v.strip().split()
                lst.append('R2')
            elif k <=361:
                lst = v.strip().split()
                lst.append('R3')
            line = '    '.join(lst) +'\n'
            f1.writelines(line)
        f2.close()
