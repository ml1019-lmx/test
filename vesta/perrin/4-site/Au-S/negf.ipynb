# %%
6.9560588348-4.7091000000+53.3107376278
# Out:
# 55.5576964626

# %%
def str_float_z(num,height):
    return str(float(num)+height)
def str_float_x(num):
    return str(float(num)-9.5967844016 +9.14789)
def str_float_y(num):
    return str(float(num)-5.0535373223+5.02957 )

with open("test.xyz",'w') as f1:
    with open("4A_rightlead_molecule(optimized).xyz") as f:
        for k,v in enumerate(f):
            lst = v.strip().split()
            if k == 0 or k == 1:
                continue
            elif k<=37:
                lst[3]=str_float_z(lst[3],18.836800+2.354600)
#                 lst[2]=str_float_y(lst[2])
#                 lst[1]=str_float_x(lst[1])
                lst.append('L0')
            elif k<=99:
                lst[3]=str_float_z(lst[3],18.836800+2.354600)
                lst.append('S')
            elif k<=136:
                lst[3]=str_float_z(lst[3], 18.836800+2.354600)
#                 lst[2]=str_float_y(lst[2])
#                 lst[1]=str_float_x(lst[1])
                lst.append('R0')
            else:
                lst[2]=str_float_y(lst[2])
                lst[1]=str_float_x(lst[1])
                #modify from R1,should be 1layer higher than last R0layer
                lst[3]=str_float_z(lst[3],-65.7291386278+64.624311+2.354600)
            line = '    '.join(lst) +'\n'
            f1.writelines(line)
        f.close()
    f1.close()
    
with open("test.xyz") as f:
    print(f.read())
# Out:
# Au    1.6649000000    0.0000000000    21.1914    L0
# Au    6.6598000000    0.0000000000    21.1914    L0
# Au    4.1623000000    1.4419000000    21.1914    L0
# Au    9.1572000000    1.4419000000    21.1914    L0
# Au    6.6598000000    2.8838000000    21.1914    L0
# Au    11.6546000000    2.8838000000    21.1914    L0
# Au    4.1623000000    4.3256000000    21.1914    L0
# Au    9.1572000000    4.3256000000    21.1914    L0
# Au    6.6598000000    5.7675000000    21.1914    L0
# Au    11.6546000000    5.7675000000    21.1914    L0
# Au    9.1572000000    7.2094000000    21.1914    L0
# Au    14.1520000000    7.2094000000    21.1914    L0
# Au    3.3299000000    0.0000000000    23.546000000000003    L0
# Au    8.3247000000    0.0000000000    23.546000000000003    L0
# Au    5.8273000000    1.4419000000    23.546000000000003    L0
# Au    10.8221000000    1.4419000000    23.546000000000003    L0
# Au    8.3247000000    2.8838000000    23.546000000000003    L0
# ...

# %%
  C         9.5967844016        5.0535373223       32.1193376278
     Au      8.324700    5.767500    45.4192882128
# Out:
#   File "<ipython-input-1-7f7fcc54c1cf>", line 1
#     C         9.5967844016        5.0535373223       32.1193376278
#                          ^
# SyntaxError: invalid syntax

# %%
85.8157163+2.3546000000
# Out:
# 88.17031630000001
