# %%
def str_float(num):
    return str(float(num)+7.063800*2)

dic={}

with open('Au-4TPA-C60-Au_cp2k_12.xyz', mode='w') as f1:
    with open('Au-4TPA-C60-Au.xyz', mode='r') as f:
        for k,v in enumerate(f):
#             if k==0 or k==1:
#                 continue
            lst=v.strip().split()
            if k<=37:
                stage='L3'
            elif k>37 and k<=73:
                stage='L2'
            elif k>73 and k<=109:
                stage='L0'
                lst[3]=str_float(lst[3])
            elif k>109 and k<=145:
                stage='L0'
                lst[3]=str_float(lst[3])
#             elif k>217 and k<=254:
#                 stage='R0'
#                 lst[3]=str_float(lst[3])
#             elif k>254 and k<=290:
#                 stage='R1'
#                 lst[3]=str_float(lst[3])
#             elif k>290 and k<=326:
#                 stage='R2'
#                 lst[3]=str_float(str_float(lst[3]))
#             elif k>316 and k<=362:
#                 stage='R3'
#                 lst[3]=str_float(str_float(lst[3]))
            else:
                stage='S'
                lst[3]=str_float(lst[3])
            lis=lst[0]+' '*6+lst[1]+' '*4+lst[2]+' '*4+lst[3]+' '+stage+'\n'
            f1.writelines(lis)
        f.close()
    f1.close()

with open('Au-4TPA-C60-Au_cp2k_12.xyz', mode='r') as f1:
    print(f1.read())
# Out:
# Au      1.664900    0.000000    0.000000 L3
# Au      6.659800    0.000000    0.000000 L3
# Au      4.162300    1.441900    0.000000 L3
# Au      9.157200    1.441900    0.000000 L3
# Au      6.659800    2.883800    0.000000 L3
# Au      11.654600    2.883800    0.000000 L3
# Au      4.162300    4.325600    0.000000 L3
# Au      9.157200    4.325600    0.000000 L3
# Au      6.659800    5.767500    0.000000 L3
# Au      11.654600    5.767500    0.000000 L3
# Au      9.157200    7.209400    0.000000 L3
# Au      14.152000    7.209400    0.000000 L3
# Au      3.329900    0.000000    2.354600 L3
# Au      8.324700    0.000000    2.354600 L3
# Au      5.827300    1.441900    2.354600 L3
# Au      10.822100    1.441900    2.354600 L3
# Au      8.324700    2.883800    2.354600 L3
# Au      13.319500    2.883800    2.354600 L3
# Au      5.827300    4.325600    2.354600 L3
# Au      10.822100    4.325600    2.354600 L3
# Au      8.324700    5.767500    2.354600 L3
# ...

# %%
with open('Au-4TPA-C60-Au_cp2k_12.txt', mode='w') as f1:
    with open('Au-4TPA-C60-Au_12.xyz', mode='r') as f:
        for k,v in enumerate(f):
            lst=v.split
            if k<=37:
                stage='L2'
            elif 37<k<=73:
                stage='L0'
            elif k>=146 and k<=182:
                stage='R0'
            elif k>=183:
                stage='R2'
            else:
                stage='S'
            lis=v.strip()+' '+stage+'\n'
            f1.writelines(lis)

# %%
print(float('7'))
# Out:
# 7.0

# %%
def str_float(num):
    return str(float(num)-21.191401)



with open('S_(ch2)1_4tpa_C60(geo).xyz', mode='w') as f1:
    with open('S_(ch2)1_4tpa_C60.xyz', mode='r') as f:
        for k,v in enumerate(f):
#             if k==0 or k==1:
#                 continue
            lst=v.strip().split()
            lst[3]=str_float(lst[3])
            lis=lst[0]+' '*6+lst[1]+' '*4+lst[2]+' '*4+lst[3]+' '+lst[4]+'\n'
            f1.writelines(lis)
        f.close()
    f1.close()

with open('S_(ch2)1_4tpa_C60(geo).xyz', mode='r') as f1:
    print(f1.read())
# Out:
# Au      1.664900    0.000000    -21.191401 L3
# Au      6.659800    0.000000    -21.191401 L3
# Au      4.162300    1.441900    -21.191401 L3
# Au      9.157200    1.441900    -21.191401 L3
# Au      6.659800    2.883800    -21.191401 L3
# Au      11.654600    2.883800    -21.191401 L3
# Au      4.162300    4.325600    -21.191401 L3
# Au      9.157200    4.325600    -21.191401 L3
# Au      6.659800    5.767500    -21.191401 L3
# Au      11.654600    5.767500    -21.191401 L3
# Au      9.157200    7.209400    -21.191401 L3
# Au      14.152000    7.209400    -21.191401 L3
# Au      3.329900    0.000000    -18.836800999999998 L3
# Au      8.324700    0.000000    -18.836800999999998 L3
# Au      5.827300    1.441900    -18.836800999999998 L3
# Au      10.822100    1.441900    -18.836800999999998 L3
# Au      8.324700    2.883800    -18.836800999999998 L3
# Au      13.319500    2.883800    -18.836800999999998 L3
# Au      5.827300    4.325600    -18.836800999999998 L3
# ...

# %%
def str_float(num):
    return str(float(num)+2.354600+18.836800)

def str_float_for3A(num):
#     to modify the distance between c60 and Au electrodes (=3A)
    return str(float(num)-(3.77291178720000187-3))

max=0.0

with open('S_(ch2)1_4tpa_C60_negf.xyz', mode='w') as f1:
    with open('S_(ch2)1_4tpa_C60.xyz', mode='r') as f:
        for k,v in enumerate(f):
#             if k==0 or k==1:
#                 continue
            lst=v.strip().split()
            if len(lst) < 5:
                lst[3]=str_float(lst[3])
                if  'Au'in lst :
                    lst.append('L0')
                else:
                    lst.append('S')
                    if float(lst[3]) > max:
                        max =float(lst[3])
            if k >=219:
                lst[3]=str_float_for3A(lst[3])
            lis=lst[0]+' '*6+lst[1]+' '*4+lst[2]+' '*4+lst[3]+' '+lst[4]+'\n'
            f1.writelines(lis)
        f.close()
    f1.close()

print(max)
with open('S_(ch2)1_4tpa_C60_negf.xyz', mode='r') as f1:
    print(f1.read())
# Out:
# 42.4192882128
# Au      1.664900    0.000000    0.000000 L3
# Au      6.659800    0.000000    0.000000 L3
# Au      4.162300    1.441900    0.000000 L3
# Au      9.157200    1.441900    0.000000 L3
# Au      6.659800    2.883800    0.000000 L3
# Au      11.654600    2.883800    0.000000 L3
# Au      4.162300    4.325600    0.000000 L3
# Au      9.157200    4.325600    0.000000 L3
# Au      6.659800    5.767500    0.000000 L3
# Au      11.654600    5.767500    0.000000 L3
# Au      9.157200    7.209400    0.000000 L3
# Au      14.152000    7.209400    0.000000 L3
# Au      3.329900    0.000000    2.354600 L3
# Au      8.324700    0.000000    2.354600 L3
# Au      5.827300    1.441900    2.354600 L3
# Au      10.822100    1.441900    2.354600 L3
# Au      8.324700    2.883800    2.354600 L3
# Au      13.319500    2.883800    2.354600 L3
# Au      5.827300    4.325600    2.354600 L3
# Au      10.822100    4.325600    2.354600 L3
# Au      8.324700    5.767500    2.354600 L3
# ...

# %%
46.192200 -42.4192882128
# Out:
# 3.7729117872000018
