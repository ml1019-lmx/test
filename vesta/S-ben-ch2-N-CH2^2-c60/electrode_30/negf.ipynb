# %%
def str_float_z(num,height):
    return str(float(num)+height)
def str_float_x(num):
    return str(float(num)+2*9.9896000000/2-4.9948000000/2)
def str_float_y(num):
    return str(float(num)+1.25*8.6512000000/2)

with open("S-ben-ch2-N-ch2^2-C60_negf_5A.xyz",'w') as f1:
    with open("wholejunction(optimized)_5A.xyz") as f:
        for k,v in enumerate(f):
            lst = v.strip().split()
            if k == 0 or k == 1:
                f1.writelines(v)
                continue
            elif k<=91:
                lst[3]=str_float_z(lst[3],19.073360+ 2.3841700000)
#                 lst[2]=str_float_y(lst[2])
#                 lst[1]=str_float_x(lst[1])
                lst.append('L0')
            elif k<=172:
                lst[3]=str_float_z(lst[3],19.073360+ 2.3841700000)
                lst.append('S')
#                 lst[2]=str_float_y(lst[2])
#                 lst[1]=str_float_x(lst[1])
            elif k<=263:
                lst[3]=str_float_z(lst[3],19.073360+ 2.3841700000)
                lst.append('R0')
            else:
                lst[3]=str_float_z(lst[3], 33.9803022578+2.38417*2+19.073360-  55.8220022578)
#                 lst[2]=str_float_y(lst[2])
#                 lst[1]=str_float_x(lst[1])
            line = '    '.join(lst) +'\n'
            f1.writelines(line)
#         for k,v in enumerate(right_lead):
#             print()
#             lst = v.strip().split()
#             lst[3]=str_float_z(lst[3],-22.872278212799998)
#             line = '    '.join(lst) +'\n'
#             f1.writelines(line)
        f.close()
    f1.close()
    
with open("wholejunction(beoforegeo)_3A.xyz") as f:
    print(f.read())
# Out:
#      262
#  i =       68, E =     -6434.1909013571
# Au    0.0000000000    0.0000000000    0.0000000000    L0
# Au    8.7600000000    0.0000000000    0.0000000000    L0
# Au    4.3800000000    7.5863820000    0.0000000000    L0
# Au    13.1400000000    7.5863820000    0.0000000000    L0
# Au    2.9200000000    0.0000000000    0.0000000000    L0
# Au    11.6800000000    0.0000000000    0.0000000000    L0
# Au    7.3000000000    7.5863820000    0.0000000000    L0
# Au    16.0599990000    7.5863820000    0.0000000000    L0
# Au    5.8400000000    0.0000000000    0.0000000000    L0
# Au    14.6000000000    0.0000000000    0.0000000000    L0
# Au    10.2200000000    7.5863820000    0.0000000000    L0
# Au    18.9800000000    7.5863820000    0.0000000000    L0
# Au    1.4600000000    2.5287940000    0.0000000000    L0
# Au    10.2200000000    2.5287940000    0.0000000000    L0
# Au    5.8400000000    10.1151760000    0.0000000000    L0
# ...

# %%
70.1132975128+2.354600
# Out:
# 72.46789751280001

# %%
72.67382+2.38417
# Out:
# 75.05799

# %%
2.843239524/0.52917721067 /2
# Out:
# 2.6864720047185395

# %%
(13.186365824-11.747788906)/0.52917721067
# Out:
# 2.7185163854252017

# %%
7.59849039*0.612729100
# Out:
# 4.65581617802335

# %%
74.58081+2.38417
# Out:
# 76.96498

# %%
#wholejunction_geo
with open("test.xyz",'w') as f1:
    with open("whole_junction(beforegeo).xyz") as f:
        for k,v in enumerate(f):
            lst = v.strip().split()
            if k == 0 or k == 1:
                f1.writelines(v)
                continue
            elif k<=91:
#                 lst[3]=str_float_z(lst[3],19.073360+ 2.3841700000)
#                 lst[2]=str_float_y(lst[2])
#                 lst[1]=str_float_x(lst[1])
                lst.append(' ')
#                 continue
            elif k<=173:
#                 lst[3]=str_float_z(lst[3],19.073360+ 2.3841700000)
                lst.append('S')
#                 lst[2]=str_float_y(lst[2])
#                 lst[1]=str_float_x(lst[1])
            else:
                lst[3]=str_float_z(lst[3], -26.89741+24.0705294069+2.38417)
#                 lst[2]=str_float_y(lst[2])
#                 lst[1]=str_float_x(lst[1])
#                 lst.append('R0')
            line = '    '.join(lst) +'\n'
            f1.writelines(line)
#         for k,v in enumerate(right_lead):
#             print()
#             lst = v.strip().split()
#             lst[3]=str_float_z(lst[3],-22.872278212799998)
#             line = '    '.join(lst) +'\n'
#             f1.writelines(line)
        f.close()
    f1.close()
    
with open("test.xyz") as f:
    print(f.read())
# Out:
# 262
#  i =       78, E =     -7630.7679613509
# Au    0.000000    0.000000    0.000000    L0
# Au    8.760000    0.000000    0.000000    L0
# Au    4.380000    7.586382    0.000000    L0
# Au    13.140000    7.586382    0.000000    L0
# Au    2.920000    0.000000    0.000000    L0
# Au    11.680000    0.000000    0.000000    L0
# Au    7.300000    7.586382    0.000000    L0
# Au    16.059999    7.586382    0.000000    L0
# Au    5.840000    0.000000    0.000000    L0
# Au    14.600000    0.000000    0.000000    L0
# Au    10.220000    7.586382    0.000000    L0
# Au    18.980000    7.586382    0.000000    L0
# Au    1.460000    2.528794    0.000000    L0
# Au    10.220000    2.528794    0.000000    L0
# Au    5.840000    10.115176    0.000000    L0
# Au    14.600000    10.115176    0.000000    L0
# Au    4.380000    2.528794    0.000000    L0
# Au    13.140000    2.528794    0.000000    L0
# Au    8.760000    10.115176    0.000000    L0
# ...

# %%
75.89364940690001+2.38417
# Out:
# 78.27781940690001
